# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import random
import math
import scipy.stats as stats
from matplotlib import dates

# %matplotlib inline

# %%
filepath = "10-02-2019.ics_1.orage"
df = pd.read_csv(filepath, header=None)
df.dropna(how='all', axis=1)
keywords=["Meeting","homework","party","Work","CA","TA","class","movie","tennis",""]
tags=["Meeting","Works","Sports","Leisure","Miscellaneous"]
df['Tag']=np.nan
df['Duration']=np.nan
df.rename(columns={0:'Activity',1:'Start-time',2:'End-time',3:'Note',4:'Location',5:'Tag',6:'Duration'},inplace=True)
df2=pd.DataFrame(columns=['Activity','Tag'])

for i,row in df.iterrows():
    currentcelltags=[]
    s=str(row['Activity'])
    for j in range(len(keywords)):
        
        if (keywords[j] in s) or (keywords[j].lower() in s):
            update=str(keywords[j])
            currentcelltags.append(update)
    
   
    if len(currentcelltags)!=1:
        data=pd.DataFrame({'Activity':[s],'Tag':[currentcelltags]})
        df2=df2.append(data)
    else:
        data=pd.DataFrame({'Activity':[s],'Tag':['Miscellaneous']})
        df2=df2.append(data)

df2
 #the activities in the new column, group the times into weeks, morning, afternoon and evening. 
# tag the activities, come up tags as much as we can, create a new column for tag, create new column for duration, create new column for morning/afternoon/evening
# Out:
#                                              Activity              Tag
# 0   GJ First Lego League Qualifier Volunteer Orien...  [Meeting, TA, ]
# 0                       Chairman's Award Team Meeting      [Meeting, ]
# 0                       Chairman's Award Team Meeting      [Meeting, ]
# 0                       Chairman's Award Team Meeting      [Meeting, ]
# 0                       Chairman's Award Team Meeting      [Meeting, ]
# 0                       Chairman's Award Team Meeting      [Meeting, ]
# 0     Chairman's Team Meeting-Review Essays/Last day!      [Meeting, ]
# 0                         Recommendations Due Feb. 18    Miscellaneous
# 0         Chairman's Award Team presenting at Chevron    Miscellaneous
# 0                 Chairman's Award Video Team Meeting      [Meeting, ]
# 0                            Chairman's Award meeting      [Meeting, ]
# 0                 Chairman's Award Video Team Meeting      [Meeting, ]
# 0               Chairman's Award Meeting on this day!      [Meeting, ]
# 0                       Chairman's Award Presentation           [TA, ]
# 0                             Chairman's team meeting      [Meeting, ]
# 0   Chairman's team meeting (rescheduled from Thur...      [Meeting, ]
# 0                Chairman's team meeting on this day!      [Meeting, ]
# 0            Chairman's team- Radio Interview at KAFM    Miscellaneous
# 0                                   Meet mrs borgmann    Miscellaneous
# 0                             Science In Action Night    Miscellaneous
# 0                                       Starlyns bday           [TA, ]
# 0                                   Final Grades In!!    Miscellaneous
# 0                                         Concessions    Miscellaneous
# 0                                         Concessions    Miscellaneous
# 0                                            Ib party        [party, ]
# 0                                         Concessions    Miscellaneous
# 0                                Team Awards Ceremony    Miscellaneous
# 0                                    Rosas Bday Party    Miscellaneous
# 0              High School Tennis Clinics - This Week    Miscellaneous
# 0              High School Tennis Clinics - This Week    Miscellaneous
# ..                                                ...              ...
# 0                                        Wallbreakers    Miscellaneous
# 0                                  Get to the Airport    Miscellaneous
# 0                                          Tree Hacks    Miscellaneous
# 0                                            FREN3200    Miscellaneous
# 0                                               Intel    Miscellaneous
# 0                    Kara MacGregor- Academic Advisor           [CA, ]
# 0                       Prof. Cheng Zhai, 2116 Siebel    Miscellaneous
# 0                     Prof. Craig Zilles, 4112 Siebel    Miscellaneous
# 0                      Prof. Nancy Amato, 2244 Siebel    Miscellaneous
# 0                          Interview Grading with Anh    Miscellaneous
# 0                        Arriving at Urbana Champlain    Miscellaneous
# 0                     Prof. Paul Fischer, 4320 Siebel    Miscellaneous
# 0                                    Morning Sessions    Miscellaneous
# 0                                               Lunch    Miscellaneous
# 0                                    ECEN4593-Phase 4    Miscellaneous
# 0                             Twitter Mock Interviews    Miscellaneous
# 0                      Student Org Rountable DLC 1B70           [TA, ]
# 0                                         Salsa Night    Miscellaneous
# 0                    Facebook Coding Workshop ECCR200         [Work, ]
# 0                                    Career Fair Tech    Miscellaneous
# 0                             Grace Hopper Conference    Miscellaneous
# 0                                               Intel    Miscellaneous
# 0                                               Intel    Miscellaneous
# 0                                               Intel    Miscellaneous
# 0                           CSCI4502- Proposal Slides    Miscellaneous
# 0                                      ECEN4593 - HW2    Miscellaneous
# 0                                               Intel    Miscellaneous
# 0                            CSCI4502-Proposal Slides    Miscellaneous
# 0                            CSCI4502-Proposal Slides    Miscellaneous
# 0                      Advanced Computer Architecture    Miscellaneous
#
# [3473 rows x 2 columns]
